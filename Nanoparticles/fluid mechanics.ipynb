# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [0.002508817,
0.001982235,
0.00175462,
0.001200039,
0.000575354,
0.000367696,
0.00253596,
0.002269298,
0.001723646,
0.001529092,
0.001178935,
0.000483996
]
developed_head =[
    
    -1.120596486,
-0.298424498,
0.213324297,
0.82854749,
1.305804819,
1.679587751,
-0.919270884,
-0.166081827,
0.483632831,
0.960890161,
1.43814749,
1.706056285

    
    
]
ouput_power = [
    -27.50619614,
-5.787646001,
3.662146066,
9.728035464,
7.350654083,
6.042326326,
-22.80857317,
-3.687447408,
8.155977943,
14.37539063,
16.58843312,
8.078811569

]

efficiency = [ -6.409712803,
-1.348683347,
0.898297296,
2.518782522,
2.015185804,
1.76003873,
-4.668232063,
-0.79244559,
1.844998662,
3.634497274,
4.753217867,
2.3148872
]

fig, ax1 = plt.subplots()

# Plot the first y-axis
ax1.plot(x, y1, 'g-', label='sin(x)')
ax1.set_xlabel('X axis')
ax1.set_ylabel('sin(x)', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.plot(x, y2, 'b-', label='cos(x)')
ax2.set_ylabel('cos(x)', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Create a third y-axis
ax3 = ax1.twinx()
ax3.plot(x, y3, 'r-', label='tan(x)')
ax3.set_ylabel('tan(x)', color='r')
ax3.tick_params(axis='y', labelcolor='r')

# Adjust the position of the third y-axis
ax3.spines['right'].set_position(('outward', 60))  # Move the third y-axis outward

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='upper center')

plt.title('Multiple Y-axes with Common X-axis')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_1, flow_rate_2 = flow_rate[:half], flow_rate[half:]
developed_head_1, developed_head_2 = developed_head[:half], developed_head[half:]
output_power_1, output_power_2 = output_power[:half], output_power[half:]
efficiency_1, efficiency_2 = efficiency[:half], efficiency[half:]

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

# Plot the first half
ax1.plot(flow_rate_1, developed_head_1, 'g-', label='Developed Head')
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head', color='g')
ax1.tick_params(axis='y', labelcolor='g')

ax1_2 = ax1.twinx()
ax1_2.plot(flow_rate_1, output_power_1, 'b-', label='Output Power')
ax1_2.set_ylabel('Output Power', color='b')
ax1_2.tick_params(axis='y', labelcolor='b')

ax1_3 = ax1.twinx()
ax1_3.plot(flow_rate_1, efficiency_1, 'r-', label='Efficiency')
ax1_3.set_ylabel('Efficiency', color='r')
ax1_3.tick_params(axis='y', labelcolor='r')
ax1_3.spines['right'].set_position(('outward', 60))

# Add legends
ax1.legend(loc='upper left')
ax1_2.legend(loc='upper right')
ax1_3.legend(loc='upper center')

# Plot the second half
ax2.plot(flow_rate_2, developed_head_2, 'g-', label='Developed Head')
ax2.set_xlabel('Flow Rate')
ax2.set_ylabel('Developed Head', color='g')
ax2.tick_params(axis='y', labelcolor='g')

ax2_2 = ax2.twinx()
ax2_2.plot(flow_rate_2, output_power_2, 'b-', label='Output Power')
ax2_2.set_ylabel('Output Power', color='b')
ax2_2.tick_params(axis='y', labelcolor='b')

ax2_3 = ax2.twinx()
ax2_3.plot(flow_rate_2, efficiency_2, 'r-', label='Efficiency')
ax2_3.set_ylabel('Efficiency', color='r')
ax2_3.tick_params(axis='y', labelcolor='r')
ax2_3.spines['right'].set_position(('outward', 60))

# Add legends
ax2.legend(loc='upper left')
ax2_2.legend(loc='upper right')
ax2_3.legend(loc='upper center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ![a](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_1 = flow_rate[:half]
developed_head_1 = developed_head[:half]
output_power_1 = output_power[:half]
efficiency_1 = efficiency[:half]

# Create the plot for the first half
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot the first y-axis
ax1.plot(flow_rate_1, developed_head_1, 'g-', label='Developed Head')
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.plot(flow_rate_1, output_power_1, 'b-', label='Output Power')
ax2.set_ylabel('Output Power', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Create a third y-axis
ax3 = ax1.twinx()
ax3.plot(flow_rate_1, efficiency_1, 'r-', label='Efficiency')
ax3.set_ylabel('Efficiency', color='r')
ax3.tick_params(axis='y', labelcolor='r')
ax3.spines['right'].set_position(('outward', 60))  # Move the third y-axis outward

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='upper center')

plt.title('1826 rpm')
#plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_2 = flow_rate[half:]
developed_head_2 = developed_head[half:]
output_power_2 = output_power[half:]
efficiency_2 = efficiency[half:]

# Create the plot for the second half
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot the first y-axis
ax1.plot(flow_rate_2, developed_head_2, 'g-', label='Developed Head')
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.plot(flow_rate_2, output_power_2, 'b-', label='Output Power')
ax2.set_ylabel('Output Power', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Create a third y-axis
ax3 = ax1.twinx()
ax3.plot(flow_rate_2, efficiency_2, 'r-', label='Efficiency')
ax3.set_ylabel('Efficiency', color='r')
ax3.tick_params(axis='y', labelcolor='r')
ax3.spines['right'].set_position(('outward', 60))  # Move the third y-axis outward

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='upper center')

plt.title('Second Half of the Data')
plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 37
#      35 ax1.scatter(flow_rate_1, developed_head_1, color='g', label='Developed Head', marker='o')
#      36 x_smooth = np.linspace(min(flow_rate_1), max(flow_rate_1), 300)
# ---> 37 y_smooth = make_interp_spline(flow_rate_1, developed_head_1)(x_smooth)
#      38 ax1.plot(x_smooth, y_smooth, 'g:', linestyle=':', linewidth=2)
#      39 ax1.set_xlabel('Flow Rate')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\interpolate\_bsplines.py:1295, in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
#    1293     raise ValueError("Expect x to not have duplicates")
#    1294 if x.ndim != 1 or np.any(x[1:] < x[:-1]):
# -> 1295     raise ValueError("Expect x to be a 1D strictly increasing sequence.")
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_1 = flow_rate[:half]
developed_head_1 = developed_head[:half]
output_power_1 = output_power[:half]
efficiency_1 = efficiency[:half]

# Create the plot for the first half
fig, ax1 = plt.subplots(figsize=(10, 6))

# Scatter plot and smooth curve for the first y-axis
ax1.scatter(flow_rate_1, developed_head_1, color='g', label='Developed Head', marker='o')
p1 = np.poly1d(np.polyfit(flow_rate_1, developed_head_1, 7))
x_smooth = np.linspace(min(flow_rate_1), max(flow_rate_1), 300)
ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head(m H2o)', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.scatter(flow_rate_1, output_power_1, color='b', label='Output Power', marker='o')
p2 = np.poly1d(np.polyfit(flow_rate_1, output_power_1, 7))
ax2.plot(x_smooth, p2(x_smooth), 'b:', linestyle=':', linewidth=1)
ax2.set_ylabel('Output Power', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Create a third y-axis
ax3 = ax1.twinx()
ax3.scatter(flow_rate_1, efficiency_1, color='r', label='Efficiency(%)', marker='o')
p3 = np.poly1d(np.polyfit(flow_rate_1, efficiency_1, 7))
ax3.plot(x_smooth, p3(x_smooth), 'r:', linestyle=':', linewidth=1)
ax3.set_ylabel('Efficiency', color='r')
ax3.tick_params(axis='y', labelcolor='r')
ax3.spines['right'].set_position(('outward', 100))  # Move the third y-axis further outward
ax3.spines['right'].set_position(('outward', 80))  # Move the third y-axis further outward
ax3.spines['right'].set_position(('outward', 60))  # Move the third y-axis outward

# Add legends
ax1.legend(loc='center right')
ax2.legend(loc='upper right')
ax3.legend(loc='center', bbox_to_anchor=(0.9, 0.7))
plt.title('1826 rpm')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_20464\906576888.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g:" (-> linestyle=':'). The keyword argument will take precedence.
#   ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_1 = flow_rate[:half]
developed_head_1 = developed_head[:half]
output_power_1 = output_power[:half]
efficiency_1 = efficiency[:half]

# Shift the efficiency values
efficiency_offset = 2
efficiency_1_shifted = [e + efficiency_offset for e in efficiency_1]

# Create the plot for the first half
fig, ax1 = plt.subplots(figsize=(10, 6))

# Scatter plot and smooth curve for the first y-axis
ax1.scatter(flow_rate_1, developed_head_1, color='g', label='Developed Head', marker='o')
p1 = np.poly1d(np.polyfit(flow_rate_1, developed_head_1, 7))
x_smooth = np.linspace(min(flow_rate_1), max(flow_rate_1), 300)
ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head(m H2o)', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.scatter(flow_rate_1, output_power_1, color='b', label='Output Power', marker='o')
p2 = np.poly1d(np.polyfit(flow_rate_1, output_power_1, 7))
ax2.plot(x_smooth, p2(x_smooth), 'b:', linestyle=':', linewidth=1)
ax2.set_ylabel('Output Power', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Create a third y-axis
ax3 = ax1.twinx()
ax3.scatter(flow_rate_1, efficiency_1_shifted, color='r', label='Efficiency(%)', marker='o')
p3 = np.poly1d(np.polyfit(flow_rate_1, efficiency_1_shifted, 7))
ax3.plot(x_smooth, p3(x_smooth), 'r:', linestyle=':', linewidth=1)
ax3.set_ylabel('Efficiency', color='r')
ax3.tick_params(axis='y', labelcolor='r')
ax3.spines['right'].set_position(('outward', 100))  # Move the third y-axis further outward

# Add legends
ax1.legend(loc='center right')
ax2.legend(loc='upper right')
ax3.legend(loc='center', bbox_to_anchor=(0.9, 0.7))
plt.title('1826 rpm')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_20464\2060499416.py:41: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g:" (-> linestyle=':'). The keyword argument will take precedence.
#   ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_1 = flow_rate[:half]
developed_head_1 = developed_head[:half]
output_power_1 = output_power[:half]
efficiency_1 = efficiency[:half]

# Create the plot for the first half
fig, ax1 = plt.subplots(figsize=(10, 6))

# Scatter plot and smooth curve for the first y-axis
ax1.scatter(flow_rate_1, developed_head_1, color='g', label='Developed Head(m of water)', marker='o')
p1 = np.poly1d(np.polyfit(flow_rate_1, developed_head_1, 7))
x_smooth = np.linspace(min(flow_rate_1), max(flow_rate_1), 300)
ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head(m H2o)', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.scatter(flow_rate_1, output_power_1, color='b', label='Output Power(W)', marker='o')
p2 = np.poly1d(np.polyfit(flow_rate_1, output_power_1, 7))
ax2.plot(x_smooth, p2(x_smooth), 'b:', linestyle=':', linewidth=1)
ax2.set_ylabel('Output Power', color='b')
ax2.tick_params(axis='y', labelcolor='b')
power_offset=1
ax2.set_ylim(ax2.get_ylim()[0] + power_offset, ax2.get_ylim()[1] + power_offset)

# Create a third y-axis
ax3 = ax1.twinx()
ax3.scatter(flow_rate_1, efficiency_1, color='r', label='Efficiency(%)', marker='o')
p3 = np.poly1d(np.polyfit(flow_rate_1, efficiency_1, 7))
ax3.plot(x_smooth, p3(x_smooth), 'r:', linestyle=':', linewidth=1)
ax3.set_ylabel('Efficiency', color='r')
ax3.tick_params(axis='y', labelcolor='r')
ax3.spines['right'].set_position(('outward', 50))  # Move the third y-axis further outward

# Shift the efficiency y-axis by adjusting its limits
efficiency_offset = -0.25
ax3.set_ylim(ax3.get_ylim()[0] + efficiency_offset, ax3.get_ylim()[1] + efficiency_offset)

# Add legends
ax1.legend(loc='center right')
ax2.legend(loc='upper right')
ax3.legend(loc='center', bbox_to_anchor=(0.9, 0.7))
plt.title('1826 rpm')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_20464\1543795038.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g:" (-> linestyle=':'). The keyword argument will take precedence.
#   ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
flow_rate = [
    0.002508817, 0.001982235, 0.00175462, 0.001200039, 0.000575354, 0.000367696,
    0.00253596, 0.002269298, 0.001723646, 0.001529092, 0.001178935, 0.000483996
]
developed_head = [
    -1.120596486, -0.298424498, 0.213324297, 0.82854749, 1.305804819, 1.679587751,
    -0.919270884, -0.166081827, 0.483632831, 0.960890161, 1.43814749, 1.706056285
]
output_power = [
    -27.50619614, -5.787646001, 3.662146066, 9.728035464, 7.350654083, 6.042326326,
    -22.80857317, -3.687447408, 8.155977943, 14.37539063, 16.58843312, 8.078811569
]
efficiency = [
    -6.409712803, -1.348683347, 0.898297296, 2.518782522, 2.015185804, 1.76003873,
    -4.668232063, -0.79244559, 1.844998662, 3.634497274, 4.753217867, 2.3148872
]

# Split the data into two halves
half = len(flow_rate) // 2

flow_rate_1 = flow_rate[half:]
developed_head_1 = developed_head[half:]
output_power_1 = output_power[half:]
efficiency_1 = efficiency[half:]

# Create the plot for the first half
fig, ax1 = plt.subplots(figsize=(10, 6))

# Scatter plot and smooth curve for the first y-axis
ax1.scatter(flow_rate_1, developed_head_1, color='g', label='Developed Head(m of water)', marker='o')
p1 = np.poly1d(np.polyfit(flow_rate_1, developed_head_1, 7))
x_smooth = np.linspace(min(flow_rate_1), max(flow_rate_1), 300)
ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
ax1.set_xlabel('Flow Rate')
ax1.set_ylabel('Developed Head(m H2o)', color='g')
ax1.tick_params(axis='y', labelcolor='g')

# Create a second y-axis
ax2 = ax1.twinx()
ax2.scatter(flow_rate_1, output_power_1, color='b', label='Output Power(W)', marker='o')
p2 = np.poly1d(np.polyfit(flow_rate_1, output_power_1, 7))
ax2.plot(x_smooth, p2(x_smooth), 'b:', linestyle=':', linewidth=1)
ax2.set_ylabel('Output Power', color='b')
ax2.tick_params(axis='y', labelcolor='b')
power_offset=1.5
ax2.set_ylim(ax2.get_ylim()[0] + power_offset, ax2.get_ylim()[1] + power_offset)

# Create a third y-axis
ax3 = ax1.twinx()
ax3.scatter(flow_rate_1, efficiency_1, color='r', label='Efficiency(%)', marker='o')
p3 = np.poly1d(np.polyfit(flow_rate_1, efficiency_1, 7))
ax3.plot(x_smooth, p3(x_smooth), 'r:', linestyle=':', linewidth=1)
ax3.set_ylabel('Efficiency', color='r')
ax3.tick_params(axis='y', labelcolor='r')
ax3.spines['right'].set_position(('outward', 50))  # Move the third y-axis further outward

# Shift the efficiency y-axis by adjusting its limits
efficiency_offset = -0.25
ax3.set_ylim(ax3.get_ylim()[0] + efficiency_offset, ax3.get_ylim()[1] + efficiency_offset)

# Add legends
ax1.legend(loc='center right' , bbox_to_anchor=(1, 0.85))
ax2.legend(loc='upper right',)
ax3.legend(loc='center', bbox_to_anchor=(0.9, 0.7))
plt.title('1980 rpm')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Temp\ipykernel_20464\2395137566.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g:" (-> linestyle=':'). The keyword argument will take precedence.
#   ax1.plot(x_smooth, p1(x_smooth), 'g:', linestyle=':', linewidth=2)
# C:\Users\defaultuser0.LAPTOP-LRB3T941\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...
